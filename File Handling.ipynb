# %%
import numpy as np
import pandas as pd

# %%
loan_data = open('Loan_prediction_dataset.csv', 'r')

# %%
data = np.genfromtxt(loan_data, delimiter=',', skip_header=1)

# %%
loan_data.close()

# %%
loan_amounts = data[:, 8]

# %%
loan_amounts
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 120., 201.,  74., 106.,
#        114., 320.,  nan, 100., 144., 184., 110.,  80.,  47.,  75., 134.,
#         96.,  88.,  44., 144., 120., 144., 100., 120., 112., 134., 286.,
#         97.,  96., 135., 180., 144., 120.,  99., 165.,  nan, 116., 258.,
#        126., 312., 125., 136., 172.,  97.,  81.,  95., 187., 113., 176.,
#        110., 180., 130., 111.,  nan, 167., 265.,  50., 136.,  99., 104.,
#        210., 175., 131., 188.,  81., 122.,  25.,  nan, 137.,  50., 115.,
#        131., 133., 151.,  nan,  nan, 160., 100., 225., 120., 216.,  94.,
#        136., 139., 152.,  nan, 118., 185., 154.,  85., 175., 259., 180.,
#         44., 137.,  81., 194.,  93., 370.,  nan, 160., 182., 650.,  74.,
#         70.,  25., 102., 290.,  84.,  88., 242., 129., 185., 168., 175.,
# ...

# %%
mean_loan = np.mean(loan_data['loan_amounts'])
median_loan = np.median(loan_data['loan_amounts'])
std_loan = np.std(loan_data['loan_amounts'])

print(f"Mean Loan Amount: {mean_loan}")
print(f"Median Loan Amount: {median_loan}")
print(f"Standard Deviation of Loan Amounts: {std_loan}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 mean_loan = np.mean(loan_data['loan_amounts'])
#       2 median_loan = np.median(loan_data['loan_amounts'])
#       3 std_loan = np.std(loan_data['loan_amounts'])
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
loan_data1 = pd.read_csv('Loan_prediction_dataset.csv')
loan_data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_data1['LoanAmount'].fillna(loan_data1['LoanAmount'].mean(), inplace=True)
loan_data1.isnull().sum()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11236\1533941213.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   loan_data1['LoanAmount'].fillna(loan_data1['LoanAmount'].mean(), inplace=True)
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# ...

# %%
mean_loan1 = np.mean(loan_data1['LoanAmount'])
median_loan2 = np.median(loan_data1['LoanAmount'])
std_loan3 = np.std(loan_data1['LoanAmount'])

print(f"Mean Loan Amount: {mean_loan1}")
print(f"Median Loan Amount: {median_loan2}")
print(f"Standard Deviation of Loan Amounts: {std_loan3}")
# Out:
# Mean Loan Amount: 145.75244299674267
# Median Loan Amount: 128.0
# Standard Deviation of Loan Amounts: 84.03871423798938
